# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D

# %%
train_datagen = IDG(rescale = 1./255,
                                   validation_split = 0.2,
                                  
        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = IDG(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = valid_datagen

# %%
train_dataset  = train_datagen.flow_from_directory(directory = r'C:\Users\shrut\OneDrive\Desktop\New folder\Alzheimer MRI Dataset\archive\Dataset2\train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 3585 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = r'C:\Users\shrut\OneDrive\Desktop\New folder\Alzheimer MRI Dataset\archive\Dataset2\val',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 254 images belonging to 4 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = r'C:\Users\shrut\OneDrive\Desktop\New folder\Alzheimer MRI Dataset\archive\Dataset2\test',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 32)
# Out:
# Found 642 images belonging to 4 classes.

# %%
WORK_DIR = r'C:\Users\shrut\OneDrive\Desktop\New folder\Alzheimer MRI Dataset\archive\Dataset'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 4176)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
#Retrieving the data from the ImageDataGenerator iterator

train_data, train_labels = train_data_gen.next()

# %%
#Getting to know the dimensions of our dataset

print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)
# C:\Users\shrut\anaconda3\envs\pallawi\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass classes=[0 1 2 3] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
resnet_model = ResNet50(input_shape=(176, 176, 3), include_top=False, weights="imagenet")

# %%
for layer in resnet_model.layers:
    layer.trainable=False

# %%
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D

# %%
# Building Model

model=Sequential()
model.add(resnet_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(4,activation='softmax'))

# %%
#Defining a custom callback function to stop training our model when accuracy goes above 99%

class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True
            
my_callback = MyCallback()

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=3)

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'),
           tfa.metrics.F1Score(num_classes=4)]

CALLBACKS = [my_callback, rop_callback]
    
model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 6, 6, 2048)        23587712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 2048)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 73728)             0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 73728)             294912
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4718656
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation (Activation)      (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32)                128
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32)                128
# _________________________________________________________________
# activation_4 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 28,613,892
# Trainable params: 4,878,212
# Non-trainable params: 23,735,680
# _________________________________________________________________

# %%
#Fit the training data to the model and validate it using the validation data
EPOCHS = 50

history = model.fit(train_data, train_labels, validation_data=(val_data, val_labels), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# Epoch 1/50
# 256/256 [==============================] - 206s 792ms/step - loss: 1.4671 - acc: 0.2706 - auc: 0.5324 - f1_score: 0.2667 - val_loss: 1.3236 - val_acc: 0.3979 - val_auc: 0.6536 - val_f1_score: 0.3158
# Epoch 2/50
# 256/256 [==============================] - 207s 808ms/step - loss: 1.3108 - acc: 0.3561 - auc: 0.6330 - f1_score: 0.3500 - val_loss: 1.0529 - val_acc: 0.5215 - val_auc: 0.8265 - val_f1_score: 0.5089
# Epoch 3/50
# 256/256 [==============================] - 201s 786ms/step - loss: 1.1509 - acc: 0.4459 - auc: 0.7412 - f1_score: 0.4402 - val_loss: 0.8534 - val_acc: 0.6265 - val_auc: 0.8795 - val_f1_score: 0.5924
# Epoch 4/50
# 256/256 [==============================] - 197s 771ms/step - loss: 1.0306 - acc: 0.5100 - auc: 0.7975 - f1_score: 0.5024 - val_loss: 0.7799 - val_acc: 0.6353 - val_auc: 0.8922 - val_f1_score: 0.5924
# Epoch 5/50
# 256/256 [==============================] - 195s 763ms/step - loss: 0.9698 - acc: 0.5432 - auc: 0.8242 - f1_score: 0.5286 - val_loss: 0.7699 - val_acc: 0.6304 - val_auc: 0.8940 - val_f1_score: 0.5669
# Epoch 6/50
# 256/256 [==============================] - 194s 760ms/step - loss: 0.9314 - acc: 0.5665 - auc: 0.8368 - f1_score: 0.5421 - val_loss: 0.7465 - val_acc: 0.6523 - val_auc: 0.9017 - val_f1_score: 0.6250
# Epoch 7/50
# 256/256 [==============================] - 194s 758ms/step - loss: 0.9151 - acc: 0.5724 - auc: 0.8434 - f1_score: 0.5516 - val_loss: 0.7361 - val_acc: 0.6562 - val_auc: 0.9042 - val_f1_score: 0.6184
# Epoch 8/50
# 256/256 [==============================] - 194s 759ms/step - loss: 0.8822 - acc: 0.5892 - auc: 0.8541 - f1_score: 0.5635 - val_loss: 0.7263 - val_acc: 0.6626 - val_auc: 0.9065 - val_f1_score: 0.6426
# Epoch 9/50
# 256/256 [==============================] - 657s 3s/step - loss: 0.8719 - acc: 0.5985 - auc: 0.8585 - f1_score: 0.5757 - val_loss: 0.7158 - val_acc: 0.6646 - val_auc: 0.9085 - val_f1_score: 0.6349
# Epoch 10/50
# 256/256 [==============================] - 195s 762ms/step - loss: 0.8759 - acc: 0.5988 - auc: 0.8591 - f1_score: 0.5762 - val_loss: 0.7045 - val_acc: 0.6582 - val_auc: 0.9100 - val_f1_score: 0.6063
# Epoch 11/50
# 256/256 [==============================] - 203s 795ms/step - loss: 0.8575 - acc: 0.6067 - auc: 0.8653 - f1_score: 0.5853 - val_loss: 0.6981 - val_acc: 0.6807 - val_auc: 0.9150 - val_f1_score: 0.6629
# Epoch 12/50
# 256/256 [==============================] - 206s 804ms/step - loss: 0.8376 - acc: 0.6212 - auc: 0.8711 - f1_score: 0.6033 - val_loss: 0.6942 - val_acc: 0.6875 - val_auc: 0.9171 - val_f1_score: 0.6697
# Epoch 13/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.8298 - acc: 0.6211 - auc: 0.8732 - f1_score: 0.6035 - val_loss: 0.6746 - val_acc: 0.6982 - val_auc: 0.9190 - val_f1_score: 0.6849
# Epoch 14/50
# 256/256 [==============================] - 207s 810ms/step - loss: 0.8275 - acc: 0.6218 - auc: 0.8755 - f1_score: 0.6060 - val_loss: 0.6669 - val_acc: 0.7012 - val_auc: 0.9243 - val_f1_score: 0.6923
# Epoch 15/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.8214 - acc: 0.6305 - auc: 0.8774 - f1_score: 0.6191 - val_loss: 0.6651 - val_acc: 0.7017 - val_auc: 0.9233 - val_f1_score: 0.6947
# Epoch 16/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.8131 - acc: 0.6367 - auc: 0.8794 - f1_score: 0.6254 - val_loss: 0.6594 - val_acc: 0.7085 - val_auc: 0.9255 - val_f1_score: 0.7020
# Epoch 17/50
# 256/256 [==============================] - 207s 808ms/step - loss: 0.8036 - acc: 0.6383 - auc: 0.8832 - f1_score: 0.6273 - val_loss: 0.6499 - val_acc: 0.7197 - val_auc: 0.9272 - val_f1_score: 0.7127
# Epoch 18/50
# 256/256 [==============================] - 207s 810ms/step - loss: 0.7893 - acc: 0.6461 - auc: 0.8872 - f1_score: 0.6384 - val_loss: 0.6467 - val_acc: 0.7139 - val_auc: 0.9305 - val_f1_score: 0.7117
# Epoch 19/50
# 256/256 [==============================] - 207s 808ms/step - loss: 0.7778 - acc: 0.6455 - auc: 0.8894 - f1_score: 0.6390 - val_loss: 0.6440 - val_acc: 0.7222 - val_auc: 0.9305 - val_f1_score: 0.7174
# Epoch 20/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.7733 - acc: 0.6525 - auc: 0.8915 - f1_score: 0.6479 - val_loss: 0.6273 - val_acc: 0.7251 - val_auc: 0.9315 - val_f1_score: 0.7176
# Epoch 21/50
# 256/256 [==============================] - 207s 808ms/step - loss: 0.7801 - acc: 0.6434 - auc: 0.8891 - f1_score: 0.6389 - val_loss: 0.6311 - val_acc: 0.7290 - val_auc: 0.9353 - val_f1_score: 0.7252
# Epoch 22/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.7652 - acc: 0.6565 - auc: 0.8941 - f1_score: 0.6503 - val_loss: 0.6240 - val_acc: 0.7310 - val_auc: 0.9358 - val_f1_score: 0.7257
# Epoch 23/50
# 256/256 [==============================] - 207s 808ms/step - loss: 0.7637 - acc: 0.6469 - auc: 0.8924 - f1_score: 0.6431 - val_loss: 0.6199 - val_acc: 0.7324 - val_auc: 0.9375 - val_f1_score: 0.7269
# Epoch 24/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7615 - acc: 0.6624 - auc: 0.8953 - f1_score: 0.6567 - val_loss: 0.6165 - val_acc: 0.7349 - val_auc: 0.9362 - val_f1_score: 0.7273
# Epoch 25/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7479 - acc: 0.6637 - auc: 0.8994 - f1_score: 0.6574 - val_loss: 0.6146 - val_acc: 0.7397 - val_auc: 0.9390 - val_f1_score: 0.7332
# Epoch 26/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7510 - acc: 0.6613 - auc: 0.8977 - f1_score: 0.6572 - val_loss: 0.6058 - val_acc: 0.7422 - val_auc: 0.9391 - val_f1_score: 0.7363
# Epoch 27/50
# 256/256 [==============================] - 207s 807ms/step - loss: 0.7378 - acc: 0.6730 - auc: 0.9016 - f1_score: 0.6715 - val_loss: 0.6089 - val_acc: 0.7344 - val_auc: 0.9395 - val_f1_score: 0.7302
# Epoch 28/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7468 - acc: 0.6710 - auc: 0.8998 - f1_score: 0.6684 - val_loss: 0.6016 - val_acc: 0.7402 - val_auc: 0.9410 - val_f1_score: 0.7363
# Epoch 29/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7342 - acc: 0.6772 - auc: 0.9026 - f1_score: 0.6753 - val_loss: 0.5991 - val_acc: 0.7412 - val_auc: 0.9414 - val_f1_score: 0.7363
# Epoch 30/50
# 256/256 [==============================] - 206s 806ms/step - loss: 0.7259 - acc: 0.6796 - auc: 0.9053 - f1_score: 0.6788 - val_loss: 0.5958 - val_acc: 0.7441 - val_auc: 0.9406 - val_f1_score: 0.7363
# Epoch 31/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.7346 - acc: 0.6742 - auc: 0.9029 - f1_score: 0.6726 - val_loss: 0.5955 - val_acc: 0.7461 - val_auc: 0.9434 - val_f1_score: 0.7414
# Epoch 32/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.7307 - acc: 0.6759 - auc: 0.9035 - f1_score: 0.6737 - val_loss: 0.5991 - val_acc: 0.7515 - val_auc: 0.9433 - val_f1_score: 0.7450
# Epoch 33/50
# 256/256 [==============================] - 206s 806ms/step - loss: 0.7184 - acc: 0.6808 - auc: 0.9071 - f1_score: 0.6782 - val_loss: 0.5939 - val_acc: 0.7490 - val_auc: 0.9438 - val_f1_score: 0.7432
# Epoch 34/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7209 - acc: 0.6775 - auc: 0.9061 - f1_score: 0.6762 - val_loss: 0.5927 - val_acc: 0.7534 - val_auc: 0.9421 - val_f1_score: 0.7462
# Epoch 35/50
# 256/256 [==============================] - 207s 808ms/step - loss: 0.7160 - acc: 0.6832 - auc: 0.9079 - f1_score: 0.6835 - val_loss: 0.5888 - val_acc: 0.7520 - val_auc: 0.9451 - val_f1_score: 0.7484
# Epoch 36/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.7121 - acc: 0.6890 - auc: 0.9091 - f1_score: 0.6870 - val_loss: 0.5818 - val_acc: 0.7583 - val_auc: 0.9463 - val_f1_score: 0.7540
# Epoch 37/50
# 256/256 [==============================] - 206s 806ms/step - loss: 0.7032 - acc: 0.6868 - auc: 0.9109 - f1_score: 0.6854 - val_loss: 0.5712 - val_acc: 0.7539 - val_auc: 0.9462 - val_f1_score: 0.7447
# Epoch 38/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7088 - acc: 0.6831 - auc: 0.9100 - f1_score: 0.6830 - val_loss: 0.5747 - val_acc: 0.7598 - val_auc: 0.9468 - val_f1_score: 0.7552
# Epoch 39/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7088 - acc: 0.6848 - auc: 0.9104 - f1_score: 0.6831 - val_loss: 0.5716 - val_acc: 0.7607 - val_auc: 0.9482 - val_f1_score: 0.7575
# Epoch 40/50
# 256/256 [==============================] - 207s 811ms/step - loss: 0.6971 - acc: 0.6908 - auc: 0.9128 - f1_score: 0.6901 - val_loss: 0.5674 - val_acc: 0.7666 - val_auc: 0.9484 - val_f1_score: 0.7623
# Epoch 41/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.6969 - acc: 0.6885 - auc: 0.9122 - f1_score: 0.6881 - val_loss: 0.5705 - val_acc: 0.7607 - val_auc: 0.9473 - val_f1_score: 0.7549
# Epoch 42/50
# 256/256 [==============================] - 206s 807ms/step - loss: 0.6845 - acc: 0.6930 - auc: 0.9153 - f1_score: 0.6932 - val_loss: 0.5612 - val_acc: 0.7632 - val_auc: 0.9474 - val_f1_score: 0.7566
# Epoch 43/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.6927 - acc: 0.6960 - auc: 0.9143 - f1_score: 0.6958 - val_loss: 0.5673 - val_acc: 0.7646 - val_auc: 0.9492 - val_f1_score: 0.7579
# Epoch 44/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.7002 - acc: 0.6886 - auc: 0.9116 - f1_score: 0.6890 - val_loss: 0.5762 - val_acc: 0.7505 - val_auc: 0.9458 - val_f1_score: 0.7370
# Epoch 45/50
# 256/256 [==============================] - 206s 805ms/step - loss: 0.6886 - acc: 0.6915 - auc: 0.9149 - f1_score: 0.6905 - val_loss: 0.5710 - val_acc: 0.7603 - val_auc: 0.9477 - val_f1_score: 0.7544
# Epoch 46/50
# 256/256 [==============================] - 9810s 38s/step - loss: 0.6686 - acc: 0.6995 - auc: 0.9188 - f1_score: 0.7004 - val_loss: 0.5657 - val_acc: 0.7632 - val_auc: 0.9485 - val_f1_score: 0.7578
# Epoch 47/50
# 256/256 [==============================] - 197s 769ms/step - loss: 0.6806 - acc: 0.7075 - auc: 0.9177 - f1_score: 0.7073 - val_loss: 0.5617 - val_acc: 0.7637 - val_auc: 0.9493 - val_f1_score: 0.7586
# Epoch 48/50
# 256/256 [==============================] - 203s 794ms/step - loss: 0.6808 - acc: 0.6976 - auc: 0.9156 - f1_score: 0.6972 - val_loss: 0.5604 - val_acc: 0.7676 - val_auc: 0.9492 - val_f1_score: 0.7619
# Epoch 49/50
# 256/256 [==============================] - 204s 797ms/step - loss: 0.6776 - acc: 0.7057 - auc: 0.9180 - f1_score: 0.7059 - val_loss: 0.5622 - val_acc: 0.7681 - val_auc: 0.9495 - val_f1_score: 0.7619
# Epoch 50/50
# 256/256 [==============================] - 203s 795ms/step - loss: 0.6733 - acc: 0.7013 - auc: 0.9178 - f1_score: 0.7014 - val_loss: 0.5640 - val_acc: 0.7666 - val_auc: 0.9486 - val_f1_score: 0.7596

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
#Evaluating the model on the data

train_scores = model.evaluate(train_data, train_labels)
val_scores = model.evaluate(val_data, val_labels)
test_scores = model.evaluate(test_data, test_labels)

print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 256/256 [==============================] - 148s 577ms/step - loss: 0.5201 - acc: 0.7965 - auc: 0.9611 - f1_score: 0.7933
# 64/64 [==============================] - 37s 584ms/step - loss: 0.5640 - acc: 0.7666 - auc: 0.9486 - f1_score: 0.7596
# 80/80 [==============================] - 49s 607ms/step - loss: 0.5824 - acc: 0.7445 - auc: 0.9436 - f1_score: 0.7420
# Training Accuracy: 79.65%
# Validation Accuracy: 76.66%
# Testing Accuracy: 74.45%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                   precision    recall  f1-score   support
#
#      NonDemented       0.80      0.83      0.81       639
# VeryMildDemented       1.00      1.00      1.00       635
#     MildDemented       0.79      0.43      0.56       662
# ModerateDemented       0.51      0.73      0.60       624
#
#        micro avg       0.74      0.74      0.74      2560
#        macro avg       0.77      0.75      0.74      2560
#     weighted avg       0.78      0.74      0.74      2560
#      samples avg       0.74      0.74      0.74      2560

# %%
#Plot the confusion matrix to understand the classification in detail

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES,
                yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)
